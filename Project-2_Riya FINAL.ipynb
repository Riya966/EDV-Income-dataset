# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Fetch the incomes dataset.

# %%
data1 = pd.read_csv("D:/AIDTM OneDrive/OneDrive - Adani University/Documents/Project-2/income.csv")
data1
# Out:
#         age     workclass  fnlwgt     education  educational-num  \
# 0      25.0       Private  226802          11th              7.0
# 1      38.0       Private   89814       HS-grad              9.0
# 2      28.0     Local-gov  336951    Assoc-acdm             12.0
# 3      44.0       Private  160323  Some-college             10.0
# 4      18.0             ?  103497  Some-college             10.0
# ...     ...           ...     ...           ...              ...
# 48837  27.0       Private  257302    Assoc-acdm             12.0
# 48838  40.0       Private  154374       HS-grad              9.0
# 48839  58.0       Private  151910       HS-grad              9.0
# 48840  22.0       Private  201490       HS-grad              9.0
# 48841  52.0  Self-emp-inc  287927       HS-grad              9.0
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data1.dtypes
# Out:
# age                float64
# workclass           object
# fnlwgt               int64
# education           object
# educational-num    float64
# marital-status      object
# occupation          object
# relationship        object
# race                object
# gender              object
# capital-gain         int64
# capital-loss         int64
# hours-per-week     float64
# native-country      object
# income              object
# dtype: object

# %% [markdown]
# ## 2. Display first 10 and last 10 rows in dataset.

# %%
data1.head(10)
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 0  25.0           Private  226802          11th              7.0
# 1  38.0           Private   89814       HS-grad              9.0
# 2  28.0         Local-gov  336951    Assoc-acdm             12.0
# 3  44.0           Private  160323  Some-college             10.0
# 4  18.0                 ?  103497  Some-college             10.0
# 5  34.0           Private  198693          10th              6.0
# 6  29.0                 ?  227026       HS-grad              9.0
# 7  63.0  Self-emp-not-inc  104626   Prof-school             15.0
# 8  24.0           Private  369667  Some-college             10.0
# 9  55.0           Private  104996       7th-8th              4.0
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
data1.tail(10)
# Out:
#         age     workclass  fnlwgt     education  educational-num  \
# 48832  32.0       Private   34066          10th              6.0
# 48833  43.0       Private   84661     Assoc-voc             11.0
# 48834  32.0       Private  116138       Masters             14.0
# 48835  53.0       Private  321865       Masters             14.0
# 48836  22.0       Private  310152  Some-college             10.0
# 48837  27.0       Private  257302    Assoc-acdm             12.0
# 48838  40.0       Private  154374       HS-grad              9.0
# 48839  58.0       Private  151910       HS-grad              9.0
# 48840  22.0       Private  201490       HS-grad              9.0
# 48841  52.0  Self-emp-inc  287927       HS-grad              9.0
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# ## 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data1.shape
# Out:
# (48842, 15)

# %% [markdown]
# ## 4. Fetch Information About  Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
print(data1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48822 non-null  float64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48829 non-null  float64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48836 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48838 non-null  float64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 5.6+ MB
# None

# %%
# rows=data.shape[0]
# print("\nTotal number of rows:",rows)
# column=data.shape[1]
# print("Total number of columns:",column)
# print("\nThe datatype of each columns are:")
# print(data.dtypes)

# %% [markdown]
# ## 5. Check Null values, outliers and duplicate data and perform data cleaning

# %%
## Cheking the null values and duplicate data from the dataset.
print("Null values per columns are:\n",data1.isnull().sum())
print()
print("Duplicate data count:",data1.duplicated().sum())
# Out:
# Null values per columns are:
#  age                20
# workclass           0
# fnlwgt              0
# education           0
# educational-num    13
# marital-status      0
# occupation          0
# relationship        6
# race                0
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week      4
# native-country      0
# income              0
# dtype: int64
#
# Duplicate data count: 52

# %%
## Replacing the ? with the nan and checking out the how many null values are there.
data1.replace('?',np.nan,inplace=True)
print("Null values per columns are:\n",data1.isnull().sum())
# Out:
# Null values per columns are:
#  age                  20
# workclass          2799
# fnlwgt                0
# education             0
# educational-num      13
# marital-status        0
# occupation         2809
# relationship          6
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        4
# native-country      857
# income                0
# dtype: int64

# %%
## cleaning the dataset thorugh dropping the null and duplicate values from the dataset.
data1.dropna(inplace=True)
data1.drop_duplicates(inplace=True)

# %%
## checking if all the null values and duplicate values are dropped or not. 
print("Null values per columns are:\n",data1.isnull().sum())
print()
print("Duplicate data count:",data1.duplicated().sum())
print(data1.shape)
# Out:
# Null values per columns are:
#  age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64
#
# Duplicate data count: 0
# (45134, 15)

# %%
## checking for the outliers in the age column.
plt.figure(figsize=(8,5))
sns.boxplot(data=data1['age'])
plt.title("box plot to detect outliers")
plt.ylabel("values")
plt.show()

# %%
## finding min and max values from the age column.
print('MIN AGE:',data1['age'].min(),'MAX AGE:',data1['age'].max())
# Out:
# MIN AGE: 17.0 MAX AGE: 90.0

# %%
## finding lower and upper bound value using IQR method.
Q1 = data1['age'].quantile(0.25)
Q3 = data1['age'].quantile(0.75)
IQR = Q3 - Q1
print("IQR is :",IQR)

lower_bound = Q1 - 1.5 * IQR  ## if we are not finding the lower bound that is also fine as age can't be negative
upper_bound = Q3 + 1.5 * IQR
print(f"Lower bound is: {lower_bound} and Upper Bound is {upper_bound} ")
# Out:
# IQR is : 19.0
# Lower bound is: -0.5 and Upper Bound is 75.5

# %%
## creating dataframe of all the outlier values.
Outliers_age = pd.DataFrame(data1[(data1['age'] < lower_bound) | (data1['age'] > upper_bound)])
print("outlier detected:")
Outliers_age
# Out:
# outlier detected:
#         age         workclass  fnlwgt     education  educational-num  \
# 0      25.0           Private  226802          11th              7.0
# 2      28.0         Local-gov  336951    Assoc-acdm             12.0
# 7      63.0  Self-emp-not-inc  104626   Prof-school             15.0
# 8      24.0           Private  369667  Some-college             10.0
# 9      55.0           Private  104996       7th-8th              4.0
# ...     ...               ...     ...           ...              ...
# 48835  53.0           Private  321865       Masters             14.0
# 48836  22.0           Private  310152  Some-college             10.0
# 48837  27.0           Private  257302    Assoc-acdm             12.0
# 48839  58.0           Private  151910       HS-grad              9.0
# 48840  22.0           Private  201490       HS-grad              9.0
#
#            marital-status         occupation   relationship   race  gender  \
# ...

# %%
## cheking for outliers in the hours-per-week column using BOX plot.
plt.figure(figsize=(8,5))
sns.boxplot(data=data1['hours-per-week'])
plt.title("box plot to detect outliers in the Hours-per-week column")
plt.ylabel("values")
plt.show()

# %%
## finding maximum and minimum value.
print('Min Hours per week:',data1['hours-per-week'].min(),'Max Hours per week:',data1['hours-per-week'].max())
# Out:
# Min Hours per week: 1.0 Max Hours per week: 99.0

# %%
## finding lower and upper bound using IQR method.
Q1 = data1['hours-per-week'].quantile(0.25)
Q3 = data1['hours-per-week'].quantile(0.75)
IQR = Q3 - Q1
print("IQR is :",IQR)

lower_bound = Q1 - 1.5 * IQR  ## if we are not finding the lower bound that is also fine as age can't be negative
upper_bound = Q3 + 1.5 * IQR
print(f"Lower bound is: {lower_bound} and Upper Bound is {upper_bound} ")
# Out:
# IQR is : 5.0
# Lower bound is: 32.5 and Upper Bound is 52.5

# %%
## creating dataframe of all the outliers.
Outliers_hours_per_week = pd.DataFrame(data1[(data1['hours-per-week'] < lower_bound) | (data1['hours-per-week'] > upper_bound)])
print("outlier detected:")
Outliers_hours_per_week
# Out:
# outlier detected:
#         age         workclass  fnlwgt     education  educational-num  \
# 5      34.0           Private  198693          10th              6.0
# 7      63.0  Self-emp-not-inc  104626   Prof-school             15.0
# 9      55.0           Private  104996       7th-8th              4.0
# 16     20.0         State-gov  444554  Some-college             10.0
# 17     43.0           Private  128354       HS-grad              9.0
# ...     ...               ...     ...           ...              ...
# 48825  31.0           Private  199655       Masters             14.0
# 48826  39.0         Local-gov  111499    Assoc-acdm             12.0
# 48829  65.0  Self-emp-not-inc   99359   Prof-school             15.0
# 48834  32.0           Private  116138       Masters             14.0
# 48840  22.0           Private  201490       HS-grad              9.0
#
#            marital-status      occupation   relationship                race  \
# ...

# %%
## cleaning the data by removing outliers and have filter out the records outside the bounds.
data_cleaned = data1[(data1['hours-per-week'] >= 32.5) & (data1['hours-per-week'] <= 52.5)]
data_cleaned
# Out:
#         age     workclass  fnlwgt     education  educational-num  \
# 0      25.0       Private  226802          11th              7.0
# 1      38.0       Private   89814       HS-grad              9.0
# 2      28.0     Local-gov  336951    Assoc-acdm             12.0
# 3      44.0       Private  160323  Some-college             10.0
# 8      24.0       Private  369667  Some-college             10.0
# ...     ...           ...     ...           ...              ...
# 48836  22.0       Private  310152  Some-college             10.0
# 48837  27.0       Private  257302    Assoc-acdm             12.0
# 48838  40.0       Private  154374       HS-grad              9.0
# 48839  58.0       Private  151910       HS-grad              9.0
# 48841  52.0  Self-emp-inc  287927       HS-grad              9.0
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %% [markdown]
# ## 6. What are the most important independent variables which affects salary range?

# %% [markdown]
# #### Checking for relationship
# #### - Race, Gender, native-Country, workclass, education,hours per week are independent varible

# %%
## relation found - Race
df=pd.crosstab(data1['race'],data1['income'])
df
# Out:
# income              <=50K   >50K
# race
# Amer-Indian-Eskimo    382     53
# Asian-Pac-Islander    932    369
# Black                3690    534
# Other                 308     45
# White               28627  10194

# %%
df.plot(kind='bar')
# Out:
# <Axes: xlabel='race'>

# %%
## Relation found - workclass
df1=pd.crosstab(data1['workclass'],data1['income'])

# %%
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='workclass'>

# %%
## Relationship found-education
df3=pd.crosstab(data1['education'],data1['income'])
df3.plot(kind='bar')
# Out:
# <Axes: xlabel='education'>

# %%
## Relationship found-gender
df4=pd.crosstab(data1['gender'],data1['income'])
df4.plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %%
## Relationship found- (native-country)
df5=pd.crosstab(data1['native-country'],data1['income'])
df5.plot(kind='bar')
# Out:
# <Axes: xlabel='native-country'>

# %%
## relation found--hours per week
df6=pd.crosstab(data1['hours-per-week'],data1['income'])
df6=df6.sort_values(by='hours-per-week',ascending= False).head(10)
df6.plot(kind='bar')
# Out:
# <Axes: xlabel='hours-per-week'>

# %%
## No relation found - Age
pd.crosstab(data1['age'],data1['income'])
# Out:
# income  <=50K  >50K
# age
# 17.0      492     0
# 18.0      693     0
# 19.0      853     2
# 20.0      913     1
# 21.0      925     6
# ...       ...   ...
# 86.0        1     0
# 87.0        1     0
# 88.0        4     1
# 89.0        1     0
# 90.0       33    12
#
# [74 rows x 2 columns]

# %%
## No relation found
df2=pd.crosstab(data1['occupation'],data1['income'])
df2.plot(kind='bar')
# Out:
# <Axes: xlabel='occupation'>

# %% [markdown]
# ## 7. What Is The Distribution of Age Column?

# %%
##plt.hist(data['age'], bins=20, color='skyblue', edgecolor='black')

## plot the figure.
plt.figure(figsize=(8,6))
sns.histplot(data1['age'],kde=True,bins=20,color='blue')

## add labels and title.
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')

## showing the plot.
plt.show()

# %% [markdown]
# ## 8. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method

# %%
age_count=data1['age'].between(17,48,inclusive='both').sum()
print("Total Number of person having age between 17 to 48:",age_count)
# Out:
# Total Number of person having age between 17 to 48: 34832

# %% [markdown]
# ## 9. What is The Distribution of Work class Column?

# %%
## couting the numbers for each value in the work class column.
work_class_count=data1['workclass'].value_counts()

## plot the data.
plt.figure(figsize=(9,6))
work_class_count.plot(kind="bar",color='pink')

## Add title and labels
plt.title("workclass Distribution",fontsize=14)
plt.xlabel("workclass",fontsize=12)
plt.ylabel("count",fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

## showing the plot.
plt.show()

# %% [markdown]
# ## 10. How Many Persons Having Bachelors or Masters Degree?

# %%
degree_count=data1[data1['education'].isin(['Bachelors','Masters'])]
print("Number of person having bachelors and Master degree:",degree_count.shape[0])
# Out:
# Number of person having bachelors and Master degree: 10064

# %% [markdown]
# ## 11. Which Work class Getting The Highest Salary?

# %%
## filter the data where income >50k
high_income=data1[data1['income']=='>50K']

# Group by workclass and count the occurrences
highest_salary_workclass=high_income['workclass'].value_counts()
highest_salary_workclass
# Out:
# workclass
# Private             7242
# Self-emp-not-inc    1058
# Local-gov            914
# Self-emp-inc         910
# Federal-gov          549
# State-gov            520
# Without-pay            2
# Name: count, dtype: int64

# %%
highest_salary_workclass=high_income['workclass'].value_counts().idxmax()
print("Workclass with the highest salary:",highest_salary_workclass)
# Out:
# Workclass with the highest salary: Private

# %% [markdown]
# ## 12. Who Has Better Chance To Get Salary >50K Male or Female ?

# %%
## filter the data where income >50k
high_income=data1[data1['income']=='>50K']

## counts the gender
gender_count = data1['gender'].value_counts()
high_income_gender_count= high_income['gender'].value_counts()

## printing both the values
print("The Total count of male and female in the dataframe:\n",gender_count)
print("\nIncome >50k count in male and female:\n",high_income_gender_count)
# Out:
# The Total count of male and female in the dataframe:
#  gender
# Male      30467
# Female    14667
# Name: count, dtype: int64
#
# Income >50k count in male and female:
#  gender
# Male      9528
# Female    1667
# Name: count, dtype: int64

# %%
## Calculate the proportion of >50K earners within each gender

proportion = (high_income_gender_count/gender_count)*100
print("Proportion of >50K earners by gender:\n",proportion)

## finding for better chance gender

better_chance_gender = proportion.idxmax()
print("\nGender with better chance to earn >50k is:",better_chance_gender)
print()
## plot the data using pie chart.
proportion.plot(kind='pie',autopct='%0.1f%%')
plt.legend()
# Out:
# Proportion of >50K earners by gender:
#  gender
# Male      31.273181
# Female    11.365651
# Name: count, dtype: float64
#
# Gender with better chance to earn >50k is: Male

# %% [markdown]
# ## 13. Perform comparative analysis of native countries for better salaries

# %%
data1['native-country'].unique()
# Out:
# array(['United-States', 'Peru', 'Guatemala', 'Mexico',
#        'Dominican-Republic', 'Germany', 'Philippines', 'Thailand',
#        'Haiti', 'El-Salvador', 'Puerto-Rico', 'Vietnam', 'South',
#        'Columbia', 'Japan', 'India', 'Cambodia', 'Poland', 'Laos',
#        'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Ireland', 'Scotland',
#        'Jamaica', 'Ecuador', 'Yugoslavia', 'Hungary', 'Hong', 'Greece',
#        'Trinadad&Tobago', 'Outlying-US(Guam-USVI-etc)', 'France',
#        'Holand-Netherlands'], dtype=object)

# %%
## filtering the salary grater than 50k(>50k)
high_income=data1[data1['income']=='>50K']

## calculating the Total count of native country
native_country_count = data1['native-country'].value_counts()
## filtering the native country withe the high_income
native_country_high_income = high_income['native-country'].value_counts()

## finding propotion of native country with the high income
country_proportion = (native_country_high_income/native_country_count)*100
country_proportion.sort_values(ascending=False)
# Out:
# native-country
# Taiwan                        45.454545
# France                        44.444444
# India                         42.176871
# England                       39.495798
# Iran                          39.285714
# Canada                        36.809816
# Greece                        35.416667
# Japan                         34.831461
# Yugoslavia                    34.782609
# Cambodia                      34.615385
# Hungary                       33.333333
# Italy                         33.000000
# China                         31.858407
# Germany                       30.051813
# Philippines                   29.787234
# Hong                          28.571429
# Ireland                       25.714286
# Cuba                          25.563910
# United-States                 25.321461
# Poland                        19.753086
# Portugal                      19.354839
# South                         17.821782
# Thailand                      17.241379
# ...

# %%
plt.figure(figsize=(10,6))

## plot the data using bar chart
country_proportion.sort_values(ascending=False).plot(kind='bar',color='blue')

## add labels and title
plt.title("proportion of >50k Earner by native Country",fontsize=15)
plt.xlabel("Native Country",fontsize=9)
plt.ylabel("proportion of >50k earners(%)",fontsize=12)

# plt.xticks(rotation=45,fontsize=9)
# plt.grid(axis='y', linestyle='--')
# plt.tight_layout()

## show the plot.
plt.show()

# %%
## Finding by the filtering the data and counting of the data.

# %%
high_income=data1[data1['income']=='>50K']
native_country_high_income = high_income['native-country'].value_counts()

count_of_native_country=data1['native-country'].value_counts()
print(count_of_native_country)
print(native_country_high_income)
# Out:
# native-country
# United-States                 41218
# Mexico                          894
# Philippines                     282
# Germany                         193
# Puerto-Rico                     175
# Canada                          163
# El-Salvador                     147
# India                           147
# Cuba                            133
# England                         119
# China                           113
# Jamaica                         103
# South                           101
# Italy                           100
# Dominican-Republic               97
# Japan                            89
# Guatemala                        84
# Vietnam                          83
# Columbia                         82
# Poland                           81
# Haiti                            69
# Portugal                         62
# Iran                             56
# Taiwan                           55
# Nicaragua                        48
# ...

# %%
# high_income=data1[data1['income']=='>50K']
# native_country_high_income = high_income['native-country'].value_counts().head()
# plt.figure(figsize=(9,6))
# native_country_high_income.plot(kind="bar",color='pink')

# plt.title("workclass Distribution",fontsize=14)
# plt.xlabel("workclass",fontsize=12)
# plt.ylabel("count",fontsize=12)
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Filter high-income data
high_income = data1[data1['income'] == '>50K']
native_country_high_income = high_income['native-country'].value_counts().head()

# Plot the data
plt.figure(figsize=(9, 6))
native_country_high_income.plot(kind="bar", color='pink')

# Add title, labels, and ticks
plt.title("Workclass Distribution (Log Scale)", fontsize=14)
plt.xlabel("Native Country", fontsize=12)
plt.ylabel("Count (Log Scale)", fontsize=12)
plt.xticks(rotation=45)

# Apply log scale to the y-axis
plt.yscale('log')

# Adjust layout
plt.tight_layout()
plt.show()
